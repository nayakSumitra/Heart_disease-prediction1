# %% [markdown]
# # 🫀 1. Heart Disease Prediction
#
# ## An End-to-End Machine Learning Classification Project
#
# ### Problem Statement
#
# The objective is to develop a Machine Learning classification model that predicts whether a person has heart disease based on medical and clinical features.
#
# The target variable is `Heart Disease`, which contains two classes:
#
# - `Absence`
# - `Presence`
#
# This project follows an end-to-end Machine Learning workflow including data collection, data understanding, EDA, data cleaning, preprocessing, model building, evaluation, cross-validation, and hyperparameter tuning.

# %% [markdown]
# ## 2. Import Necessary Libraries
#
# The following Python libraries are used for data manipulation, visualization, preprocessing, Machine Learning model building, model evaluation, cross-validation, and hyperparameter tuning.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import (
    train_test_split,
    cross_val_score,
    StratifiedKFold,
    GridSearchCV,
    RandomizedSearchCV
)

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    roc_curve,
    roc_auc_score,
    classification_report
)

import joblib

# %% [markdown]
# ## 3. Data Collection
#
# The Heart Disease Prediction dataset is used for this project.
#
# The dataset is obtained from Kaggle and is based on real-world medical data. It contains clinical features related to heart disease and a target variable indicating the presence or absence of heart disease.

# %% [markdown]
# ## Dataset Source
#
# The dataset used in this project is the **Heart Disease Prediction dataset**, obtained from **Kaggle**.
#
# The dataset is based on real-world medical data and is used for Machine Learning analysis and educational purposes.

# %%
df = pd.read_csv(
    r"C:\Users\sujee\Desktop\Heart_disease prediction1\Heart_Disease_Prediction.csv"
)

df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...
